# %% [markdown]
# # Kung Fu Robot: MuJoCo Motion Replay
#
# Run this notebook in Google Colab. It installs dependencies, uploads a `*_pose_motion.json` file, renders a MuJoCo replay, and displays the output video.

# %%
# !pip install -q -r requirements-colab.txt

# %%
from google.colab import files

uploaded = files.upload()
motion_json = next(name for name in uploaded if name.endswith("_pose_motion.json"))
motion_json

# %%
# !python render_mujoco_motion.py "$motion_json" --output mujoco_motion_replay.mp4

# %%
from IPython.display import Video

Video("mujoco_motion_replay.mp4", embed=True)

# %%
files.download("mujoco_motion_replay.mp4")
